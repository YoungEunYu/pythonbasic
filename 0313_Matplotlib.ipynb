# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.title('plot')
plt.plot([1, 4, 9, 16])
plt.show()

# %%
# title()는 플롯의 제목을 의미.
plt.title('x ticks')
plt.plot([10,20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
# 한글 제목은 깨지는 것을 볼 수 있다.

plt.title('한글 제목')
plt.plot([10,20, 30, 40], [1, 4, 9, 16])
plt.show()
# Out:
# /Users/ye/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ye/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ye/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ye/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ye/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
# 시스템 폰트 경로 리스트
font_list = mpl.font_manager.findSystemFonts()
print(font_list)
# Out:
# ['/Users/ye/Library/Fonts/WalbaumBook-ItalicExpert.otf', '/Users/ye/Library/Fonts/AntiqueOliveStd-Italic.otf', '/System/Library/Fonts/SFCompactItalic.ttf', '/Users/ye/Library/Fonts/JoannaMTStd-BoldItalic.otf', '/System/Library/Fonts/Supplemental/PTSerifCaption.ttc', '/Users/ye/Library/Fonts/GOYANGDEOGYANG EB.TTF', '/Users/ye/Library/Fonts/BenguiatEF-BoldItalic.otf', '/Users/ye/Library/Fonts/Gotham-Black.otf', '/Users/ye/Library/Fonts/NanumGothicEco.otf', '/Users/ye/Library/Fonts/MetaBoldTurk-Caps.otf', '/Users/ye/Library/Fonts/AvantGardEF-ExtraLight.otf', '/System/Library/Fonts/Supplemental/Trattatello.ttf', '/Users/ye/Library/Fonts/NeutraTextTF-DemiItalicAlt.otf', '/Users/ye/Library/Fonts/LEXN2IDP.TTF', '/Users/ye/Library/Fonts/Helvetica-Condensed-Light-Li.ttf', '/Users/ye/Library/Fonts/MatrixScriptBookOldstyle Regular.ttf', '/System/Library/Fonts/Supplemental/NotoSansThaana-Regular.ttf', '/Users/ye/Library/Fonts/Amplitude-Ultra.ttf', '/Users/ye/Library/Fonts/LEXN1IFP.TTF', '/Users/
# ...

# %%
# 폰트 설정하기
prop = mpl.font_manager.FontProperties(fname = '/Users/ye/23_Data analysis/fonts/NotoSansKR')
plt.rcParams['font.family'] = prop.get_family()

# %%
# 한글 제목은 깨지는 것을 볼 수 있다.

plt.title('한글 제목')
plt.plot([10,20, 30, 40], [1, 4, 9, 16])
plt.show()
# Out:
# /Users/ye/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ye/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ye/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ye/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ye/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
# %pwd
# Out:
# '/Users/ye/23_Data analysis'

# %%
import matplotlib as mpl
# Add every font at the specified location
# 이렇게 해두면 fonts 폴더 안에 있는 폰트들 사이에서 알아서 찾아온다.
font_dir = ['/Users/ye/23_Data analysis/fonts']

# 이름 뭐 있는지 찾아서 출력해라!
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# Noto Sans KR
# Noto Sans KR
# NanumMyeongjo
# Noto Sans KR
# NanumGothic
# NanumGothic
# NanumMyeongjo
# NanumGothic
# NanumMyeongjo
# Noto Sans KR
# Noto Sans KR
# Noto Sans KR

# %%
# Set font family globally
# 노토 산스 불러와라!

mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %%
# 한글 제목 이제 잘 됨!

plt.title('한글 제목')
plt.plot([10,20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
# https://matplotlib.org/stable/api/matplotlib_configuration_api.html#matplotlib.RcParams
# 필요에 따라 RcParams 관련 도큐먼트 보고 설정 사용하면 된다.
# font.(cursive, family, fantasy, monospace, sans-serif, serif, size, stretch, style, variant, weight )

# %%
plt.title('한글 제목')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel('엑스축 레이블')
plt.ylabel('와이축 레이블')
plt.show()

# %%
mpl.rcParams['font.family'] = 'NanumMyeongjo'
print(mpl.rcParams['font.family'])
# Out:
# ['NanumMyeongjo']

# %%
# 만약 객체마다 별도의 폰트를 적용하고 싶을때는 다음과 같이
# font family, color, size를 dict 타입으로 정의하고, 
# 이 dict 변수를 plot method의 fontdict 키워드 인수로 전달하면 된다.

title_font = {'family': 'NanumMyeongjo',
             'size': 24,
             'color': 'black'}
xlabel_font = {'family': 'NanumGothic',
              'size': 18,
              'weight': 'bold',
              'color': 'darkred'}
ylabel_font = {'family': 'NanumGothic',
              'size': 12,
              'weight': 'light',
              'color': 'blue'}

plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.title('한글 제목', fontdict = title_font)
plt.xlabel('엑스 축', fontdict = xlabel_font)
plt.ylabel('엑스 축', fontdict = ylabel_font)
# Out:
# Text(0, 0.5, '엑스 축')

# %%
# 유니코드로 음수 부호 문자표기법을 설정한다.
mpl.rc('axes', unicode_minus=False)

# %%
# style 설정하기
plt.title('default style plot')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
# 선의 스타일을 rp-- 인수 사용해서 빨간 점선으로 만듦
# --는 점선 스타일을 의미한다. 
# rp는 red pentagon을 의미.

plt.title("'rs--' 스타일의 plot")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rp--')
plt.show()

# %%
# 스타일 문자열은 색상, 마커, 선 종류의 순서로 지정된다.
# 만약 이 중 일부가 생략되면 디폴트값이 적용된다.
# 축약어를 사용한다.

# 색상 도큐먼트 여기 사용하면 됨
# https://matplotlib.org/2.0.2/examples/color/named_colors.html

# Style 설정하기 - marker
# https://matplotlib.org/2.0.2/api/markers_api.html?highlight=marker#module-matplotlib.markers

# Style 설정하기 - linestyle
# https://matplotlib.org/2.0.2/api/lines_api.html?highlight=line%20style#matplotlib.lines.Line2D.set_linestyle

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c = 'b',
        lw = 5, ls='--', marker = 'o',ms = 15, mec = 'g', mew = 5, mfc = 'r')
plt.title('스타일 적용 예')
plt.show()

# %%
plt.title('x축, y축의 범위 설정')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
        c = 'b', lw = 5, ls = '--', marker = 'o', ms = 15, mec='g', mew=5, mfc='r')
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %%
# 플롯이나 차트에서 축 상의 위치 표시 지점을 틱이라고 한다.
# 이 틱에 써진 숫자 혹은 글자를 틱 라벨이라고 한다. 
# 틱의 위치나 틱 라벨은 matplotlib가 자동으로 정해주지만 만약 수동으로 설정하고 싶다면 xticks()나 yticks를 사용.

# %%
import numpy as np

X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title('x축과 y축의 tick label 설정')
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks([-1, 0, +1])
plt.show()

# %%
# 틱 라벨 문자열에는 $$ 사이에 수학 문자식을 넣을 수도 있다.
# Mathmatical expression들의 도큐먼트 링크
# https://matplotlib.org/3.1.1/tutorials/text/mathtext.html


X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title('TeX, 문자열로 tick label 정의')
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1],
          ['Low', 'Zero', 'High'])
plt.show()

# %%
t = np.arange(0., 5., 0.2)
plt.title('라인 플롯에서 여러개의 선 그리기')
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# %%
# 복수의 plot()을 한 그림에서 표현할 수도 있다.

plt.title('복수의 plot()을 한 그림에서 표현')
style1 = {'c':'b', 'lw':'5', 'ls':'--', 'marker':'o', 'ms':'15', 'mec':'g', 'mew':'5', 'mfc':'r'}
style2 = {'c':'k', 'lw':'3', 'ls':':', 'marker':'s', 'ms':'10', 'mec':'m', 'mew':'5', 'mfc':'c'}

plt.plot([1,4,9,16], **style1)
plt.plot([9, 16, 4, 1], **style2)

plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title('legend를 표시한 플롯')
plt.plot(X, C, ls='--', label = 'cosine')
plt.plot(X, S, ls=':', label = 'sine')
plt.legend(loc=2) #upper left
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label = 'cosine')
plt.xlabel('time')
plt.ylabel('amplitude')
plt.title('cosine plot')
plt.show()

# %%
plt.title('섭씨 온도와 화씨 온도')

x = np.arange(32,100)
y = (x-32)*5/9

plt.plot([x], [y], 'o')

plt.xlabel('화씨 온도')
plt.ylabel('섭씨 온도')
plt.show()

# %%
# 두 개의 플롯을 하나의 figure 안에 그리려면 아래와 같이 명령

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2*np.pi*x1)*np.exp(-x1)
y2 = np.cos(2*np.pi*x2)

ax1 = plt.subplot(2,1,1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2,1,2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title('axes 1')

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title('axes 2')

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title('axes 3')

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title('axes 4')

plt.tight_layout()
plt.show()

# %%
# subplots()에 인수를 두 개만 전달하면 복수의 axes 객체를 동시에 생성할 수도 있다.
# 이 때는 2차원 ndarray 형태로 axes 객체가 반환된다.

fig, axes = plt.subplots(2,2)

np.random.seed(0)
axes[0,0].plot(np.random.rand(5))
axes[0,0].set_title('axes 1')
axes[0,1].plot(np.random.rand(5))
axes[0,1].set_title('axes 2')
axes[1,0].plot(np.random.rand(5))
axes[1,0].set_title('axes 3')
axes[1,1].plot(np.random.rand(5))
axes[1,1].set_title('axes 4')

plt.tight_layout()
plt.show()

# %%
plt.subplots(2,2)

# %% [markdown]
# ## fig, ax0 = plt.subplots()
#
# ax1 = ax0.twinx()
# ax0.set_title('2개의 y축 한 figure에서 사용하기')
# ax0.plot([10, 5, 2, 9, 7], 'r-', label='y0')
# ax0.set_ylabel('y0')
# ax0.grid(False)
# ax1.plot([100, 200, 220, 180, 120], 'g:', label='y1')
# ax1.set_ylabel('y1')
# ax1.grid(False)
# ax0.set_xlabel('공유되는 x축')
#
# plt.show()

# %%
import seaborn as sns
import numpy as np
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.alive.value_counts()
live = titanic.alive.value_counts()

# %%
live[0]
# Out:
# 549

# %%
live[1]
# Out:
# 342

# %%
live.rename({'no':'사망자', 'yes':'생존자'}, inplace=True)
live

alive = live.index
value = live.values
bar_colors = ['red', 'green']

plt.title('타이타닉호 생존 여부')
plt.barh(alive, value, color=bar_colors)
plt.xlabel('인원 수')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/pj/m08knkgx3rz6pmvhgttqvmyc0000gn/T/ipykernel_19880/436425122.py in <module>
#       8 plt.title('타이타닉호 생존 여부')
#       9 plt.barh(alive, value, color=bar_colors)
# ---> 10 plt.xlabel('인원 수')
#      11 plt.show()
#
# TypeError: 'str' object is not callable

# %%
# 카테고리 별 값의 상대적인 비교를 해야 할 때는 pie 명령으로 파이 차트를 그릴 수 있습니다.
labels = ['월세', '전세', '자가', '기타']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1, 0)
plt.title('Pie Chart')
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
       autopct = '%1.1f%%', shadow=True, startangle=90)
plt.axis('equal') # 원의 형태를 유지
plt.show()

# %%
import pandas as pd

# %%
# bin 영역을 넘어가면 NaN으로 분류된다.
bins = [1, 20, 30, 50, 70, 100]
labels = ['미성년자', '청년', '장년', '중년', '노년']

c = pd.cut(titanic.age, bins=bins, labels=labels).value_counts(True).dropna()

explode = (0.1, 0, 0, 0, 0)
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral', 'orange']

plt.pie(c.values, explode=explode, labels=c.index, colors=colors,
       autopct = '%1.1f%%', shadow=True, startangle=90)

plt.axis('equal')
plt.show()

# %%
np.random.seed(0)
X = np.random.randn(1000)
plt.title('Histogram')
arrays, bins, patches=plt.hist(X, bins=10)
plt.show()

# %%
arrays
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %%
np.random.seed(0)
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
plt.title('Scatter Plot')
plt.scatter(X, Y)
plt.show()

# %%
# 데이터가 2차원이 아니라 3차원 혹은 4차원인 경우에는 점 하나의 크기 혹은 색깔을 이용해 다른 데이터 값을 나타낼 수도 있다.
# 이런 차트를 버블 차트라고 한다. 
# 크기를 s 인수로 색은 c인수로 지정한다.

N = 30
np.random.seed(0)
X = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2

plt.title('Bubble Chart')
plt.scatter(X, y1, c=y2, s=y3)
plt.show()

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title('mnist digits; 0')
plt.imshow(X, interpolation = 'nearest', cmap=plt.cm.bone_r)

plt.xticks([])
plt.yticks([])

plt.grid(False)

plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65) # 크기 조정
plt.show()

# %%
# 데이터 수치를 색으로 바꾸는 함수는 칼라맵이라고 한다.
# 10개만 뽑아보자.
# 칼라맵은 cmp인수로 지정한다. 아래에 일부 칼라맵을 표시

dir(plt.cm)[:10]
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
fig, axes = plt.subplots(1, 4, figsize=(12,3),
                        subplot_kw={'xticks': [], 'yticks':[]})
axes[0].set_title('plt.cm.Blues')
axes[0].imshow(X, interpolation='nearest', cmap=plt.cm.Blues)
axes[1].set_title('plt.cm.Blues_r')
axes[1].imshow(X, interpolation='nearest', cmap=plt.cm.Blues_r)
axes[2].set_title('plt.cm.BrBG')
axes[2].imshow(X, interpolation='nearest', cmap=plt.cm.BrBG)
axes[3].set_title('plt.cm.BrBG_r')
axes[3].imshow(X, interpolation='nearest', cmap=plt.cm.BrBG_r)

# %%
# 다양한 2차원 인터폴레이션

methods = {
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36',
    'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian',
    'bessel', 'mitchell', 'sinc', 'lanczos'
}
fig, axes = plt.subplots(3, 6, figsize = (12, 6),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap = plt.cm.bone_r, interpolation = interp_method)
    ax.set_title(interp_method)
    
plt.show()

# %%
# 컨투어 플롯
# 입력 변수가 x,y 두개이고 출력 변수가 z 하나인 경우에는 3차원 자료가 된다.
# 3차원 자료는 등고선을 사용해 시각화한다.
# contour(등고선만 표시) 혹은 contourf(색으로 표시) 명령을 사용한다.
# 입력 변수 x,y는 그대로 사용할 수 없고 meshgrid 명령으로 그리드 포인트 행렬을 만들어야 한다.

def f(x,y):
    return (1-x/2+x**5+y**3) * np.exp(-x ** 2 - y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
XX, YY = np.meshgrid(x,y)
ZZ = f(XX, YY)

plt.title('Contour plots')
plt.contourf(XX, YY, ZZ, alpha=.75, cmap='jet')
plt.contour(XX, YY, ZZ, colors = 'black')
plt.show()

# %%
# 3차원 플롯은 등고선 플롯과 달리 Axes3D라는 3차원 전용 axes를 생성하여 입체적으로 표시한다.
# plot_wireframe(), plot_surface 명령을 사용한다.


from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)

XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

fig=plt.figure()
ax=Axes3D(fig)
ax.set_title('3D Surface Plot')
ax.plot_surface(XX, YY, ZZ, rstride=1, cstride=1, cmap='hot')
plt.show()
# Out:
# /var/folders/pj/m08knkgx3rz6pmvhgttqvmyc0000gn/T/ipykernel_19880/3501244500.py:14: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax=Axes3D(fig)
